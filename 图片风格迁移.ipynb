# %%
import torch
import torchvision
import torch.nn as nn
from torchvision import models, transforms
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from __future__ import division
import os
os.environ['KMP_DUPLICATE_LIB_OK']='TRUE'
# %matplotlib inline

# %%
print(torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# True

# %%
def load_image(image_path, transform=None, max_size=None, shape=None):
    image = Image.open(image_path)
    if max_size:
        scale = max_size / max(image.size)
        size = np.array(image.size)* scale
        image = image.resize(size.astype(int), Image.ANTIALIAS)
    
    if shape:
        image = image.resize(shape, Image.LANCZOS)
        
    if transform:
        image = transform(image).unsqueeze(0)
        
    return image.to(device)

# %%
unloader = transforms.ToPILImage()
plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()
    image = image.squeeze(0)
    image = unloader(image)
    plt.imshow(image)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)
    
plt.figure()

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])
content = load_image('input.png', transform, max_size=400)
style = load_image('style.png', transform, shape=[content.size(2), content.size(3)])

# %%
imshow(content[0], title='Image')

# %%
imshow(style[0], title='Image')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])
content = load_image('input.png', transform, max_size=400)
style = load_image('style.png', transform, shape=[content.size(2), content.size(3)])

# %%
imshow(content[0], title='Image')

# %%
imshow(style[0], title='Image')

# %%
content.shape, style.shape
# Out:
# (torch.Size([1, 3, 250, 400]), torch.Size([1, 3, 400, 250]))

# %%
class VGG_Net(nn.Module):
    def __init__(self):
        super(VGG_Net, self).__init__()
        self.select = ['0', '5', '10', '19', '28']
        self.vgg = models.vgg19(pretrained=True).features
        
    def forward(self, x):
        features = []
        for name, layer in self.vgg._modules.items():
            x = layer(x)
            if name in self.select:
                features.append(x)
        return features

vgg = VGG_Net().to(device).eval()

# %%
# vgg = models.vgg19(pretrained=True)

# %%
# vgg.features

# %%
features = vgg(content)

# %%
# print(type(features))
# len(features)

# %%
for feat in features:
    print(feat.shape)
# Out:
# torch.Size([1, 64, 250, 400])
# torch.Size([1, 128, 125, 200])
# torch.Size([1, 256, 62, 100])
# torch.Size([1, 512, 31, 50])
# torch.Size([1, 512, 15, 25])

# %%
target = content.clone().requires_grad_(True)
optimizer = torch.optim.Adam([target], lr=0.003, betas=[0.5, 0.999])

# %%
total_step = 2000
for step in range(total_step):
    target_features = vgg(target)
    content_features = vgg(content)
    style_features = vgg(style)
    
    content_loss = style_loss = 0.
    for f1, f2, f3 in zip(target_features, content_features, style_features):
        content_loss += torch.mean((f1-f2)**2)
        _, c, h, w = f1.size()
        f1 = f1.view(c, h*w)
        f3 = f3.view(c, h*w)
        
        f1 = torch.mm(f1, f1.t())
        f3 = torch.mm(f3, f3.t())
        style_loss += torch.mean((f1-f3)**2) / (c*h*w)
        
    loss = content_loss + style_loss * 100.
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if step % 10 == 0:
        print('step [{}/{}], Content Loss: {:.4f}, Stype Loss: {:.4f}'.format(step, total_step, content_loss.item(), style_loss.item()))
# Out:
# step [0/2000], Content Loss: 0.0000, Stype Loss: 528.9539
# step [10/2000], Content Loss: 5.6802, Stype Loss: 383.7931
# step [20/2000], Content Loss: 12.4649, Stype Loss: 279.8659
# step [30/2000], Content Loss: 18.0499, Stype Loss: 207.5740
# step [40/2000], Content Loss: 21.8769, Stype Loss: 164.5715
# step [50/2000], Content Loss: 24.5552, Stype Loss: 138.4601
# step [60/2000], Content Loss: 26.5774, Stype Loss: 121.0931
# step [70/2000], Content Loss: 28.2098, Stype Loss: 108.5764
# step [80/2000], Content Loss: 29.5751, Stype Loss: 99.0388
# step [90/2000], Content Loss: 30.7375, Stype Loss: 91.4398
# step [100/2000], Content Loss: 31.7528, Stype Loss: 85.1516
# step [110/2000], Content Loss: 32.6748, Stype Loss: 79.8384
# step [120/2000], Content Loss: 33.4936, Stype Loss: 75.2860
# step [130/2000], Content Loss: 34.2543, Stype Loss: 71.2984
# step [140/2000], Content Loss: 34.9514, Stype Loss: 67.7772
# step [150/2000], Content Loss: 35.6057, Stype Loss: 64.6352
# step [160/2000], Content Loss: 36.2214, Stype Loss: 61.8181
# step [170/2000], Content Loss: 36.7979, Stype Loss: 59.2710
# step [180/2000], Content Loss: 37.3442, Stype Loss: 56.9404
# step [190/2000], Content Loss: 37.8576, Stype Loss: 54.8065
# step [200/2000], Content Loss: 38.3257, Stype Loss: 52.8484
# step [210/2000], Content Loss: 38.7689, Stype Loss: 51.0349
# step [220/2000], Content Loss: 39.1981, Stype Loss: 49.3564
# step [230/2000], Content Loss: 39.6205, Stype Loss: 47.7928
# step [240/2000], Content Loss: 40.0221, Stype Loss: 46.3374
# step [250/2000], Content Loss: 40.3989, Stype Loss: 44.9779
# step [260/2000], Content Loss: 40.7556, Stype Loss: 43.7011
# step [270/2000], Content Loss: 41.0935, Stype Loss: 42.4971
# step [280/2000], Content Loss: 41.4208, Stype Loss: 41.3630
# step [290/2000], Content Loss: 41.7360, Stype Loss: 40.2897
# step [300/2000], Content Loss: 42.0418, Stype Loss: 39.2725
# step [310/2000], Content Loss: 42.3435, Stype Loss: 38.3052
# step [320/2000], Content Loss: 42.6343, Stype Loss: 37.3850
# step [330/2000], Content Loss: 42.9167, Stype Loss: 36.5147
# step [340/2000], Content Loss: 43.1909, Stype Loss: 35.6877
# step [350/2000], Content Loss: 43.4605, Stype Loss: 34.8993
# step [360/2000], Content Loss: 43.7169, Stype Loss: 34.1450
# step [370/2000], Content Loss: 43.9622, Stype Loss: 33.4233
# step [380/2000], Content Loss: 44.1979, Stype Loss: 32.7338
# step [390/2000], Content Loss: 44.4265, Stype Loss: 32.0740
# step [400/2000], Content Loss: 44.6567, Stype Loss: 31.4414
# step [410/2000], Content Loss: 44.8817, Stype Loss: 30.8324
# step [420/2000], Content Loss: 45.1036, Stype Loss: 30.2462
# step [430/2000], Content Loss: 45.3175, Stype Loss: 29.6836
# step [440/2000], Content Loss: 45.5304, Stype Loss: 29.1413
# step [450/2000], Content Loss: 45.7342, Stype Loss: 28.6200
# step [460/2000], Content Loss: 45.9357, Stype Loss: 28.1166
# step [470/2000], Content Loss: 46.1265, Stype Loss: 27.6316
# step [480/2000], Content Loss: 46.3103, Stype Loss: 27.1644
# step [490/2000], Content Loss: 46.4931, Stype Loss: 26.7128
# step [500/2000], Content Loss: 46.6709, Stype Loss: 26.2766
# step [510/2000], Content Loss: 46.8408, Stype Loss: 25.8559
# step [520/2000], Content Loss: 47.0059, Stype Loss: 25.4487
# step [530/2000], Content Loss: 47.1708, Stype Loss: 25.0532
# step [540/2000], Content Loss: 47.3314, Stype Loss: 24.6697
# step [550/2000], Content Loss: 47.4904, Stype Loss: 24.2977
# step [560/2000], Content Loss: 47.6483, Stype Loss: 23.9356
# step [570/2000], Content Loss: 47.8031, Stype Loss: 23.5824
# step [580/2000], Content Loss: 47.9547, Stype Loss: 23.2379
# step [590/2000], Content Loss: 48.1044, Stype Loss: 22.9031
# step [600/2000], Content Loss: 48.2505, Stype Loss: 22.5776
# step [610/2000], Content Loss: 48.3950, Stype Loss: 22.2619
# step [620/2000], Content Loss: 48.5342, Stype Loss: 21.9550
# step [630/2000], Content Loss: 48.6716, Stype Loss: 21.6563
# step [640/2000], Content Loss: 48.8051, Stype Loss: 21.3663
# step [650/2000], Content Loss: 48.9411, Stype Loss: 21.0831
# step [660/2000], Content Loss: 49.0708, Stype Loss: 20.8090
# step [670/2000], Content Loss: 49.1977, Stype Loss: 20.5426
# step [680/2000], Content Loss: 49.3207, Stype Loss: 20.2842
# step [690/2000], Content Loss: 49.4416, Stype Loss: 20.0322
# step [700/2000], Content Loss: 49.5623, Stype Loss: 19.7855
# step [710/2000], Content Loss: 49.6835, Stype Loss: 19.5451
# step [720/2000], Content Loss: 49.8032, Stype Loss: 19.3110
# step [730/2000], Content Loss: 49.9199, Stype Loss: 19.0817
# step [740/2000], Content Loss: 50.0354, Stype Loss: 18.8588
# step [750/2000], Content Loss: 50.1477, Stype Loss: 18.6408
# step [760/2000], Content Loss: 50.2622, Stype Loss: 18.4280
# step [770/2000], Content Loss: 50.3727, Stype Loss: 18.2204
# step [780/2000], Content Loss: 50.4793, Stype Loss: 18.0172
# step [790/2000], Content Loss: 50.5848, Stype Loss: 17.8186
# step [800/2000], Content Loss: 50.6888, Stype Loss: 17.6243
# step [810/2000], Content Loss: 50.7878, Stype Loss: 17.4333
# step [820/2000], Content Loss: 50.8874, Stype Loss: 17.2463
# step [830/2000], Content Loss: 50.9864, Stype Loss: 17.0629
# step [840/2000], Content Loss: 51.0865, Stype Loss: 16.8831
# step [850/2000], Content Loss: 51.1860, Stype Loss: 16.7068
# step [860/2000], Content Loss: 51.2854, Stype Loss: 16.5335
# step [870/2000], Content Loss: 51.3814, Stype Loss: 16.3634
# step [880/2000], Content Loss: 51.4743, Stype Loss: 16.1968
# step [890/2000], Content Loss: 51.5711, Stype Loss: 16.0335
# step [900/2000], Content Loss: 51.6623, Stype Loss: 15.8730
# step [910/2000], Content Loss: 51.7513, Stype Loss: 15.7157
# step [920/2000], Content Loss: 51.8410, Stype Loss: 15.5609
# step [930/2000], Content Loss: 51.9294, Stype Loss: 15.4098
# step [940/2000], Content Loss: 52.0170, Stype Loss: 15.2613
# step [950/2000], Content Loss: 52.1045, Stype Loss: 15.1156
# step [960/2000], Content Loss: 52.1921, Stype Loss: 14.9718
# step [970/2000], Content Loss: 52.2777, Stype Loss: 14.8303
# step [980/2000], Content Loss: 52.3650, Stype Loss: 14.6913
# step [990/2000], Content Loss: 52.4515, Stype Loss: 14.5548
# step [1000/2000], Content Loss: 52.5335, Stype Loss: 14.4204
# step [1010/2000], Content Loss: 52.6192, Stype Loss: 14.2876
# step [1020/2000], Content Loss: 52.7029, Stype Loss: 14.1575
# step [1030/2000], Content Loss: 52.7879, Stype Loss: 14.0285
# step [1040/2000], Content Loss: 52.8659, Stype Loss: 13.9015
# step [1050/2000], Content Loss: 52.9463, Stype Loss: 13.7763
# step [1060/2000], Content Loss: 53.0255, Stype Loss: 13.6527
# step [1070/2000], Content Loss: 53.1019, Stype Loss: 13.5306
# step [1080/2000], Content Loss: 53.1770, Stype Loss: 13.4100
# step [1090/2000], Content Loss: 53.2516, Stype Loss: 13.2916
# step [1100/2000], Content Loss: 53.3284, Stype Loss: 13.1752
# step [1110/2000], Content Loss: 53.4022, Stype Loss: 13.0605
# step [1120/2000], Content Loss: 53.4767, Stype Loss: 12.9480
# step [1130/2000], Content Loss: 53.5509, Stype Loss: 12.8369
# step [1140/2000], Content Loss: 53.6208, Stype Loss: 12.7280
# step [1150/2000], Content Loss: 53.6926, Stype Loss: 12.6207
# step [1160/2000], Content Loss: 53.7621, Stype Loss: 12.5148
# step [1170/2000], Content Loss: 53.8306, Stype Loss: 12.4104
# step [1180/2000], Content Loss: 53.8970, Stype Loss: 12.3073
# step [1190/2000], Content Loss: 53.9672, Stype Loss: 12.2058
# step [1200/2000], Content Loss: 54.0353, Stype Loss: 12.1050
# step [1210/2000], Content Loss: 54.1008, Stype Loss: 12.0058
# step [1220/2000], Content Loss: 54.1695, Stype Loss: 11.9077
# step [1230/2000], Content Loss: 54.2363, Stype Loss: 11.8107
# step [1240/2000], Content Loss: 54.3000, Stype Loss: 11.7151
# step [1250/2000], Content Loss: 54.3648, Stype Loss: 11.6209
# step [1260/2000], Content Loss: 54.4296, Stype Loss: 11.5276
# step [1270/2000], Content Loss: 54.4917, Stype Loss: 11.4355
# step [1280/2000], Content Loss: 54.5536, Stype Loss: 11.3443
# step [1290/2000], Content Loss: 54.6150, Stype Loss: 11.2545
# step [1300/2000], Content Loss: 54.6733, Stype Loss: 11.1656
# step [1310/2000], Content Loss: 54.7320, Stype Loss: 11.0780
# step [1320/2000], Content Loss: 54.7919, Stype Loss: 10.9916
# step [1330/2000], Content Loss: 54.8467, Stype Loss: 10.9064
# step [1340/2000], Content Loss: 54.9042, Stype Loss: 10.8218
# step [1350/2000], Content Loss: 54.9636, Stype Loss: 10.7382
# step [1360/2000], Content Loss: 55.0215, Stype Loss: 10.6557
# step [1370/2000], Content Loss: 55.0778, Stype Loss: 10.5742
# step [1380/2000], Content Loss: 55.1325, Stype Loss: 10.4936
# step [1390/2000], Content Loss: 55.1854, Stype Loss: 10.4139
# step [1400/2000], Content Loss: 55.2419, Stype Loss: 10.3354
# step [1410/2000], Content Loss: 55.2937, Stype Loss: 10.2577
# step [1420/2000], Content Loss: 55.3465, Stype Loss: 10.1809
# step [1430/2000], Content Loss: 55.4003, Stype Loss: 10.1052
# step [1440/2000], Content Loss: 55.4550, Stype Loss: 10.0304
# step [1450/2000], Content Loss: 55.5067, Stype Loss: 9.9567
# step [1460/2000], Content Loss: 55.5565, Stype Loss: 9.8840
# step [1470/2000], Content Loss: 55.6046, Stype Loss: 9.8117
# step [1480/2000], Content Loss: 55.6551, Stype Loss: 9.7404
# step [1490/2000], Content Loss: 55.7035, Stype Loss: 9.6699
# step [1500/2000], Content Loss: 55.7507, Stype Loss: 9.6003
# step [1510/2000], Content Loss: 55.7966, Stype Loss: 9.5315
# step [1520/2000], Content Loss: 55.8436, Stype Loss: 9.4634
# step [1530/2000], Content Loss: 55.8877, Stype Loss: 9.3963
# step [1540/2000], Content Loss: 55.9312, Stype Loss: 9.3297
# step [1550/2000], Content Loss: 55.9788, Stype Loss: 9.2636
# step [1560/2000], Content Loss: 56.0237, Stype Loss: 9.1987
# step [1570/2000], Content Loss: 56.0681, Stype Loss: 9.1343
# step [1580/2000], Content Loss: 56.1116, Stype Loss: 9.0706
# step [1590/2000], Content Loss: 56.1550, Stype Loss: 9.0073
# step [1600/2000], Content Loss: 56.1974, Stype Loss: 8.9450
# step [1610/2000], Content Loss: 56.2408, Stype Loss: 8.8832
# step [1620/2000], Content Loss: 56.2844, Stype Loss: 8.8220
# step [1630/2000], Content Loss: 56.3242, Stype Loss: 8.7615
# step [1640/2000], Content Loss: 56.3685, Stype Loss: 8.7018
# step [1650/2000], Content Loss: 56.4093, Stype Loss: 8.6429
# step [1660/2000], Content Loss: 56.4479, Stype Loss: 8.5845
# step [1670/2000], Content Loss: 56.4897, Stype Loss: 8.5268
# step [1680/2000], Content Loss: 56.5276, Stype Loss: 8.4697
# step [1690/2000], Content Loss: 56.5693, Stype Loss: 8.4133
# step [1700/2000], Content Loss: 56.6131, Stype Loss: 8.3572
# step [1710/2000], Content Loss: 56.6544, Stype Loss: 8.3016
# step [1720/2000], Content Loss: 56.6928, Stype Loss: 8.2467
# step [1730/2000], Content Loss: 56.7328, Stype Loss: 8.1924
# step [1740/2000], Content Loss: 56.7755, Stype Loss: 8.1388
# step [1750/2000], Content Loss: 56.8155, Stype Loss: 8.0858
# step [1760/2000], Content Loss: 56.8561, Stype Loss: 8.0335
# step [1770/2000], Content Loss: 56.8937, Stype Loss: 7.9821
# step [1780/2000], Content Loss: 56.9328, Stype Loss: 7.9308
# step [1790/2000], Content Loss: 56.9733, Stype Loss: 7.8804
# step [1800/2000], Content Loss: 57.0086, Stype Loss: 7.8307
# step [1810/2000], Content Loss: 57.0442, Stype Loss: 7.7817
# step [1820/2000], Content Loss: 57.0766, Stype Loss: 7.7333
# step [1830/2000], Content Loss: 57.1132, Stype Loss: 7.6857
# step [1840/2000], Content Loss: 57.1455, Stype Loss: 7.6386
# step [1850/2000], Content Loss: 57.1823, Stype Loss: 7.5917
# step [1860/2000], Content Loss: 57.2152, Stype Loss: 7.5456
# step [1870/2000], Content Loss: 57.2446, Stype Loss: 7.4999
# step [1880/2000], Content Loss: 57.2776, Stype Loss: 7.4548
# step [1890/2000], Content Loss: 57.3112, Stype Loss: 7.4100
# step [1900/2000], Content Loss: 57.3459, Stype Loss: 7.3656
# step [1910/2000], Content Loss: 57.3855, Stype Loss: 7.3219
# step [1920/2000], Content Loss: 57.4199, Stype Loss: 7.2787
# step [1930/2000], Content Loss: 57.4469, Stype Loss: 7.2359
# step [1940/2000], Content Loss: 57.4848, Stype Loss: 7.1939
# step [1950/2000], Content Loss: 57.5257, Stype Loss: 7.1525
# step [1960/2000], Content Loss: 57.5567, Stype Loss: 7.1112
# step [1970/2000], Content Loss: 57.5883, Stype Loss: 7.0707
# step [1980/2000], Content Loss: 57.6256, Stype Loss: 7.0303
# step [1990/2000], Content Loss: 57.6573, Stype Loss: 6.9904

# %%
denorm = transforms.Normalize([-2.12, -2.04, -1.80], [4.37, 4.46, 4.44])
img = target.clone().squeeze()
img = denorm(img).clamp_(0, 1)
imshow(img, title='Target Image')
